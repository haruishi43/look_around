# %%
import os
import sys

# %%
sys.path.append("..")

# %%
import cv2
import numpy as np
import torch

# %%
from LookAround.FindView.sim import FindViewSim
from LookAround.FindView.rotation_tracker import RotationTracker
# Out:
# /home/ubuntu/.pyenv/versions/3.8.8/lib/python3.8/site-packages/setuptools/distutils_patch.py:25: UserWarning: Distutils was imported before Setuptools. This usage is discouraged and may exhibit undesirable behaviors or errors. Please use Setuptools' objects directly or at least import Setuptools first.
#   warnings.warn(

# %% [markdown]
# Params:
#
# Need to fix this later

# %%
img_path = "../data/sun360/indoor/bedroom/pano_afvwdfmjeaglsd.jpg"
initial_rots = {
    "roll": 0,
    "pitch": 0,
    "yaw": 0,
}
target_rots = {
    "roll": 0,
    "pitch": 1,
    "yaw": 1,
}

# %%
num_steps = 2000
dtype = torch.float32
height = 256
width = 256
fov = 90.0
sampling_mode = "bilinear"

# %% [markdown]
# Initialize simulator

# %%
sim = FindViewSim(
    height=height,
    width=width,
    fov=fov,
    sampling_mode=sampling_mode,
)
sim.inititialize_loader(
    dtype=dtype,
    device=torch.device('cpu'),
)
sim.load_episode(
    equi_path=img_path,
    initial_rotation=initial_rots,
    target_rotation=target_rots,
)
rot_tracker = RotationTracker(
    inc=1,
    pitch_threshold=60,
)
rot_tracker.reset(initial_rots)
# Out:
# NOTE: Using loading to cpu with index: None

# %% [markdown]
# Get perspective and target images

# %%
target = sim.render_target()
pers = sim.render_pers()

# %%
from IPython.display import Image, display
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(cv2.cvtColor(pers, cv2.COLOR_BGR2RGB))

# %%
plt.imshow(cv2.cvtColor(target, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Feature matching to active vision

# %%
gray_pers = cv2.cvtColor(pers, cv2.COLOR_BGR2GRAY)
gray_target = cv2.cvtColor(target, cv2.COLOR_BGR2GRAY)

# %%
sift_detector = cv2.SIFT_create()

# %%
orb_detector = cv2.ORB_create()

# %%
(kps_pers, des_pers) = orb_detector.detectAndCompute(gray_pers, None)
(kps_target, des_target) = orb_detector.detectAndCompute(gray_target, None)

# %%
len(kps_pers)
# Out:
# 155

# %%
len(kps_target)
# Out:
# 149

# %%
kps_pers[0].pt
# Out:
# (56.0, 84.0)

# %%
kps = np.float32([kp.pt for kp in kps_pers])
# print(kps)

# %%
matcher = cv2.BFMatcher(normType=cv2.NORM_HAMMING, crossCheck=False)

# %%
# change normType for detector
raw_matches = matcher.knnMatch(des_pers, des_target, k=2)
matches = []
for m, n in raw_matches:
    if m.distance < 0.75 * n.distance:
        matches.append(m)

# %%
len(matches)
# Out:
# 107

# %%
match_img = cv2.drawMatches(gray_pers, kps_pers, gray_target, kps_target, matches, None, flags=cv2.DrawMatchesFlags_NOT_DRAW_SINGLE_POINTS)

# %%
plt.imshow(cv2.cvtColor(match_img, cv2.COLOR_BGR2RGB))

# %%
# FIXME: are query and train, src and target?
pts_pers = np.float32([kps_pers[m.queryIdx].pt for m in matches]).reshape(-1, 1, 2)
pts_target = np.float32([kps_target[m.trainIdx].pt for m in matches]).reshape(-1, 1, 2)

# %%
M, mask = cv2.findHomography(pts_pers, pts_target, cv2.RANSAC, 5.0)

# %% [markdown]
# Homography matrix doesn't make sense...

# %%
M
# Out:
# array([[ 1.00129248e+00, -1.91355296e-02, -1.39719507e+00],
#        [ 1.13982386e-02,  9.64923344e-01,  4.02628907e+00],
#        [ 1.10835869e-04, -1.79736765e-04,  1.00000000e+00]])

# %%
actions = []

for m in matches:
    
    print(m.distance, m.queryIdx, m.trainIdx)
    if m.distance > 20:
        print(">>> far")
        continue
    
    # location in the perspective image
    print(kps_pers[m.queryIdx].pt)
    # locatin in the target image
    print(kps_target[m.trainIdx].pt)
    
    pers_loc = np.float32(kps_pers[m.queryIdx].pt)
    target_loc = np.float32(kps_target[m.trainIdx].pt)
    
    x_displacement = np.abs(pers_loc[0] - target_loc[0])
    y_displacement = np.abs(pers_loc[1] - target_loc[1])
        
    if 0 < x_displacement < 1 and 0 < y_displacement < 1:
        action = "stop"
    else:
        if x_displacement >= y_displacement:
            if pers_loc[0] > target_loc[0]:
                action = "right"
            elif pers_loc[0] < target_loc[0]:
                action = "left"
            else:
                print("this shouldn't occur...")
                action = "stop"
        elif x_displacement < y_displacement:
            if pers_loc[1] > target_loc[1]:
                action = "down"
            elif pers_loc[1] < target_loc[1]:
                action = "up"
            else:
                print("this shouldn't occur...")
                action = "stop"
        else:
            action = "stop"

    
    actions.append(action)
# Out:
# 7.0 0 0
# (56.0, 84.0)
# (54.0, 86.0)
# 20.0 1 47
# (51.0, 87.0)
# (48.0, 88.80000305175781)
# 20.0 2 1
# (70.0, 89.0)
# (69.0, 92.0)
# 25.0 3 1
# >>> far
# 9.0 5 3
# (51.0, 100.0)
# (48.0, 102.0)
# 23.0 6 6
# >>> far
# 3.0 7 5
# (51.0, 104.0)
# (48.0, 106.0)
# 18.0 8 7
# (62.0, 104.0)
# (60.0, 106.0)
# 21.0 11 55
# >>> far
# 18.0 12 9
# (65.0, 106.0)
# (62.0, 108.0)
# 21.0 13 11
# >>> far
# 13.0 16 14
# (69.0, 112.0)
# (66.0, 114.0)
# 5.0 17 15
# (65.0, 113.0)
# (62.0, 115.0)
# 11.0 18 16
# (74.0, 113.0)
# (71.0, 115.0)
# 16.0 19 64
# (67.0, 116.0)
# (63.60000228881836, 120.00000762939453)
# 11.0 21 21
# (69.0, 139.0)
# (66.0, 142.0)
# 16.0 22 22
# (79.0, 139.0)
# (76.0, 142.0)
# 12.0 23 23
# (69.0, 145.0)
# (66.0, 148.0)
# 18.0 24 24
# (79.0, 146.0)
# (76.0, 148.0)
# 10.0 25 25
# (126.0, 157.0)
# (124.0, 159.0)
# 21.0 26 26
# >>> far
# 12.0 27 27
# (192.0, 175.0)
# (189.0, 177.0)
# 21.0 28 29
# >>> far
# 21.0 29 30
# >>> far
# 11.0 30 31
# (195.0, 181.0)
# (193.0, 183.0)
# 9.0 31 32
# (200.0, 185.0)
# (198.0, 187.0)
# 12.0 34 34
# (200.0, 190.0)
# (197.0, 192.0)
# 18.0 35 35
# (130.0, 191.0)
# (127.0, 194.0)
# 7.0 36 36
# (193.0, 192.0)
# (191.0, 194.0)
# 37.0 39 39
# >>> far
# 17.0 40 40
# (68.0, 204.0)
# (65.0, 208.0)
# 18.0 42 41
# (56.0, 216.0)
# (52.0, 220.0)
# 17.0 43 42
# (99.0, 216.0)
# (96.0, 220.0)
# 30.0 45 45
# >>> far
# 7.0 49 46
# (54.000003814697266, 82.80000305175781)
# (51.60000228881836, 85.20000457763672)
# 10.0 50 47
# (50.400001525878906, 86.4000015258789)
# (48.0, 88.80000305175781)
# 18.0 51 86
# (69.60000610351562, 88.80000305175781)
# (67.68000030517578, 90.72000122070312)
# 13.0 54 52
# (60.000003814697266, 103.20000457763672)
# (57.60000228881836, 105.60000610351562)
# 13.0 55 53
# (62.400001525878906, 103.20000457763672)
# (60.000003814697266, 105.60000610351562)
# 12.0 56 51
# (50.400001525878906, 104.4000015258789)
# (48.0, 105.60000610351562)
# 10.0 57 54
# (56.400001525878906, 105.60000610351562)
# (54.000003814697266, 108.00000762939453)
# 28.0 60 55
# >>> far
# 6.0 63 60
# (63.60000228881836, 112.80000305175781)
# (61.20000076293945, 115.20000457763672)
# 10.0 64 61
# (74.4000015258789, 112.80000305175781)
# (72.0, 115.20000457763672)
# 7.0 65 62
# (70.80000305175781, 115.20000457763672)
# (68.4000015258789, 117.60000610351562)
# 15.0 67 65
# (68.4000015258789, 139.20001220703125)
# (66.0, 141.60000610351562)
# 14.0 68 66
# (78.0, 139.20001220703125)
# (75.60000610351562, 141.60000610351562)
# 19.0 69 67
# (68.4000015258789, 145.20001220703125)
# (66.0, 147.60000610351562)
# 10.0 70 68
# (79.20000457763672, 145.20001220703125)
# (75.60000610351562, 147.60000610351562)
# 5.0 72 71
# (126.00000762939453, 166.8000030517578)
# (123.60000610351562, 169.20001220703125)
# 10.0 73 72
# (190.8000030517578, 174.0)
# (188.40000915527344, 176.40000915527344)
# 19.0 74 73
# (126.00000762939453, 176.40000915527344)
# (123.60000610351562, 180.0)
# 19.0 75 74
# (128.40000915527344, 177.60000610351562)
# (126.00000762939453, 180.0)
# 12.0 77 76
# (194.40000915527344, 180.0)
# (192.0, 182.40000915527344)
# 4.0 80 78
# (199.20001220703125, 189.60000610351562)
# (196.8000030517578, 192.0)
# 6.0 81 79
# (129.60000610351562, 190.8000030517578)
# (127.20000457763672, 193.20001220703125)
# 6.0 82 81
# (195.60000610351562, 192.0)
# (193.20001220703125, 194.40000915527344)
# 44.0 83 82
# >>> far
# 23.0 91 50
# >>> far
# 14.0 92 89
# (50.400001525878906, 103.68000793457031)
# (47.52000045776367, 106.56000518798828)
# 10.0 93 90
# (56.160003662109375, 105.12000274658203)
# (53.28000259399414, 108.00000762939453)
# 18.0 94 116
# (60.480003356933594, 105.12000274658203)
# (58.75200653076172, 107.1360092163086)
# 9.0 95 92
# (69.12000274658203, 106.56000518798828)
# (66.24000549316406, 108.00000762939453)
# 3.0 96 94
# (67.68000030517578, 112.32000732421875)
# (64.80000305175781, 113.76000213623047)
# 15.0 98 97
# (70.56000518798828, 115.20000457763672)
# (67.68000030517578, 118.08000183105469)
# 13.0 99 96
# (64.80000305175781, 116.64000701904297)
# (61.92000198364258, 118.08000183105469)
# 21.0 100 98
# >>> far
# 29.0 101 99
# >>> far
# 31.0 102 100
# >>> far
# 24.0 103 100
# >>> far
# 21.0 104 101
# >>> far
# 17.0 105 103
# (191.52000427246094, 174.24000549316406)
# (190.0800018310547, 175.6800079345703)
# 20.0 106 104
# (126.72000122070312, 177.12001037597656)
# (123.84000396728516, 180.0)
# 31.0 108 76
# >>> far
# 14.0 109 106
# (119.52000427246094, 187.20001220703125)
# (116.64000701904297, 190.0800018310547)
# 15.0 113 110
# (59.040000915527344, 194.40000915527344)
# (56.160003662109375, 197.28001403808594)
# 11.0 114 81
# (195.8400115966797, 194.40000915527344)
# (193.20001220703125, 194.40000915527344)
# 19.0 116 112
# (67.68000030517578, 204.48001098632812)
# (64.80000305175781, 207.36001586914062)
# 10.0 118 113
# (69.12001037597656, 88.12800598144531)
# (67.39200592041016, 91.5840072631836)
# 13.0 119 114
# (70.84800720214844, 91.5840072631836)
# (67.39200592041016, 95.04000854492188)
# 16.0 120 138
# (69.12001037597656, 95.04000854492188)
# (66.35520935058594, 97.45921325683594)
# 14.0 121 116
# (60.48000717163086, 105.40801239013672)
# (58.75200653076172, 107.1360092163086)
# 22.0 124 120
# >>> far
# 19.0 125 121
# (74.30400848388672, 117.50401306152344)
# (70.84800720214844, 119.23200988769531)
# 46.0 126 99
# >>> far
# 20.0 128 125
# (77.760009765625, 145.15200805664062)
# (76.0320053100586, 146.88002014160156)
# 12.0 129 126
# (126.14401245117188, 153.79200744628906)
# (124.416015625, 155.52001953125)
# 12.0 130 127
# (191.80801391601562, 174.52801513671875)
# (188.35202026367188, 176.25601196289062)
# 12.0 131 128
# (126.14401245117188, 176.25601196289062)
# (124.416015625, 177.98402404785156)
# 11.0 134 131
# (119.23200988769531, 186.6240234375)
# (115.77600860595703, 190.08001708984375)
# 13.0 135 132
# (129.60000610351562, 191.80801391601562)
# (127.87200927734375, 193.5360107421875)
# 5.0 136 133
# (191.80801391601562, 191.80801391601562)
# (190.08001708984375, 195.26402282714844)
# 11.0 137 135
# (58.75200653076172, 193.5360107421875)
# (55.29600524902344, 196.9920196533203)
# 9.0 138 134
# (195.26402282714844, 193.5360107421875)
# (193.5360107421875, 195.26402282714844)
# 10.0 140 137
# (68.4288101196289, 89.16481018066406)
# (66.35520935058594, 91.23841094970703)
# 7.0 141 138
# (68.4288101196289, 95.38561248779297)
# (66.35520935058594, 97.45921325683594)
# 22.0 143 140
# >>> far
# 24.0 144 141
# >>> far
# 10.0 145 142
# (68.4288101196289, 141.00482177734375)
# (66.35520935058594, 143.0784149169922)
# 14.0 146 143
# (76.72321319580078, 141.00482177734375)
# (74.64961242675781, 143.0784149169922)
# 6.0 147 144
# (126.48961639404297, 153.44642639160156)
# (124.416015625, 155.52001953125)
# 5.0 148 146
# (132.71041870117188, 176.2560272216797)
# (130.63682556152344, 178.32962036132812)
# 16.0 150 131
# (118.1952133178711, 186.6240234375)
# (115.77600860595703, 190.08001708984375)
# 29.0 151 143
# >>> far
# 5.0 152 147
# (126.90435028076172, 151.7875518798828)
# (124.41603088378906, 154.27587890625)
# 23.0 153 146
# >>> far
# 11.0 154 148
# (125.41136169433594, 152.28521728515625)
# (122.42537689208984, 155.27120971679688)

# %%
actions
# Out:
# ['right',
#  'right',
#  'up',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'up',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'up',
#  'right',
#  'up',
#  'right',
#  'right',
#  'right',
#  'right',
#  'up',
#  'right',
#  'up',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'up',
#  'up',
#  'up',
#  'right',
#  'right',
#  'right',
#  'up',
#  'up',
#  'right',
#  'up',
#  'up',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'up',
#  'right',
#  'up',
#  'up',
#  'right',
#  'right',
#  'right',
#  'right',
#  'up',
#  'up',
#  'right',
#  'up',
#  'right',
#  'right',
#  'up',
#  'up',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'right',
#  'up',
#  'up',
#  'up']

# %%
dst = cv2.warpPerspective(pers, M, (pers.shape[1], pers.shape[0]))

# %%
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
